# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('data/air_pollution_2024.csv')
df
# Out:
#          id  pm25  pm10    o3    co  no2  so2   ws   wd  temp  rh   bp  rain  \
# 0       02t  33.0   NaN   NaN   NaN  NaN  NaN  0.7   49  30.0  53  754   0.0
# 1       02t  41.0   NaN   NaN   NaN  NaN  NaN  0.8   51  29.5  55  753   0.0
# 2       02t  34.0   NaN   NaN   NaN  NaN  NaN  0.4    5  29.1  57  753   0.0
# 3       02t  34.0   NaN   NaN   NaN  NaN  NaN  0.4   30  28.5  60  753   0.0
# 4       02t  36.0   NaN   NaN   NaN  NaN  NaN  0.7   19  28.1  62  753   0.0
# ...     ...   ...   ...   ...   ...  ...  ...  ...  ...   ...  ..  ...   ...
# 129538  93t  11.0  23.0  24.0  0.21  2.0  NaN  3.7   34  26.9  74  756   0.0
# 129539  93t  12.0  24.0  23.0  0.20  1.0  NaN  3.8   30  26.5  77  756   0.0
# 129540  93t  14.0  25.0  22.0  0.20  2.0  NaN  3.4   21  26.1  79  757   0.0
# 129541  93t  15.0  29.0  20.0  0.20  2.0  NaN  2.2  360  25.2  83  757   0.0
# 129542  93t   NaN   NaN   NaN   NaN  NaN  NaN  0.0    0   0.0   0    0   0.0
#
#               date      time
# ...

# %%
df.shape
# Out:
# (129543, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129543 entries, 0 to 129542
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      129543 non-null  object
#  1   pm25    123031 non-null  float64
#  2   pm10    63715 non-null   float64
#  3   o3      53826 non-null   float64
#  4   co      43968 non-null   float64
#  5   no2     43886 non-null   float64
#  6   so2     26356 non-null   float64
#  7   ws      129543 non-null  float64
#  8   wd      129543 non-null  int64
#  9   temp    129543 non-null  float64
#  10  rh      129543 non-null  int64
#  11  bp      129543 non-null  int64
#  12  rain    129543 non-null  float64
#  13  date    129543 non-null  object
#  14  time    129543 non-null  object
# dtypes: float64(9), int64(3), object(3)
# memory usage: 14.8+ MB

# %%
df.describe()
# Out:
#                 pm25          pm10            o3            co           no2  \
# count  123031.000000  63715.000000  53826.000000  43968.000000  43886.000000
# mean       30.406467     54.702032     27.635492      0.634761     10.413959
# std        17.175113     29.699532     18.309754      0.807313     10.445641
# min         0.000000      3.000000      1.000000      0.010000      1.000000
# 25%        18.000000     34.000000     13.000000      0.340000      3.000000
# 50%        27.000000     49.000000     25.000000      0.500000      7.000000
# 75%        39.000000     69.000000     39.000000      0.730000     14.000000
# max       225.000000    565.000000    176.000000     73.760000     97.000000
#
#                 so2             ws             wd           temp  \
# count  26356.000000  129543.000000  129543.000000  129543.000000
# mean       1.776749       3.076013     120.264190      22.477011
# std        2.313475      15.162843     116.267871      11.372664
# ...

# %% [markdown]
# # จำนวนวัน

# %%
df['date'].nunique()
# Out:
# 63

# %%
df['date'].unique()
# Out:
# array(['2023-12-01', '2023-12-02', '2023-12-03', '2023-12-04',
#        '2023-12-05', '2023-12-06', '2023-12-07', '2023-12-08',
#        '2023-12-09', '2023-12-10', '2023-12-11', '2023-12-12',
#        '2023-12-13', '2023-12-14', '2023-12-15', '2023-12-16',
#        '2023-12-17', '2023-12-18', '2023-12-19', '2023-12-20',
#        '2023-12-21', '2023-12-22', '2023-12-23', '2023-12-24',
#        '2023-12-25', '2023-12-26', '2023-12-27', '2023-12-28',
#        '2023-12-29', '2023-12-30', '2023-12-31', '2024-01-01',
#        '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05',
#        '2024-01-06', '2024-01-07', '2024-01-08', '2024-01-09',
#        '2024-01-10', '2024-01-11', '2024-01-12', '2024-01-13',
#        '2024-01-14', '2024-01-15', '2024-01-16', '2024-01-17',
#        '2024-01-18', '2024-01-19', '2024-01-20', '2024-01-21',
#        '2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25',
#        '2024-01-26', '2024-01-27', '2024-01-28', '2024-01-29',
# ...

# %% [markdown]
# # จำนวนเวลา

# %%
df['time'].nunique()
# Out:
# 24

# %%
df['time'].unique()
# Out:
# array(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#        '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00',
#        '10:00:00', '11:00:00', '12:00:00', '13:00:00', '14:00:00',
#        '15:00:00', '16:00:00', '17:00:00', '18:00:00', '19:00:00',
#        '20:00:00', '21:00:00', '22:00:00', '23:00:00'], dtype=object)

# %%
df.isnull().sum()
# Out:
# id           0
# pm25      6512
# pm10     65828
# o3       75717
# co       85575
# no2      85657
# so2     103187
# ws           0
# wd           0
# temp         0
# rh           0
# bp           0
# rain         0
# date         0
# time         0
# dtype: int64

# %%
# !pip install missingno

# %%
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
df = df[['id', 'date', 'time', 'pm25', 'pm10', 'o3', 'co', 'no2', 'so2']]
df
# Out:
#          id        date      time  pm25  pm10    o3    co  no2  so2
# 0       02t  2023-12-01  00:00:00  33.0   NaN   NaN   NaN  NaN  NaN
# 1       02t  2023-12-01  01:00:00  41.0   NaN   NaN   NaN  NaN  NaN
# 2       02t  2023-12-01  02:00:00  34.0   NaN   NaN   NaN  NaN  NaN
# 3       02t  2023-12-01  03:00:00  34.0   NaN   NaN   NaN  NaN  NaN
# 4       02t  2023-12-01  04:00:00  36.0   NaN   NaN   NaN  NaN  NaN
# ...     ...         ...       ...   ...   ...   ...   ...  ...  ...
# 129538  93t  2024-01-31  20:00:00  11.0  23.0  24.0  0.21  2.0  NaN
# 129539  93t  2024-01-31  21:00:00  12.0  24.0  23.0  0.20  1.0  NaN
# 129540  93t  2024-01-31  22:00:00  14.0  25.0  22.0  0.20  2.0  NaN
# 129541  93t  2024-01-31  23:00:00  15.0  29.0  20.0  0.20  2.0  NaN
# 129542  93t  2024-02-01  00:00:00   NaN   NaN   NaN   NaN  NaN  NaN
#
# [129543 rows x 9 columns]

# %%
fill_df = df.copy()
fill_df
# Out:
#          id        date      time  pm25  pm10    o3    co  no2  so2
# 0       02t  2023-12-01  00:00:00  33.0   NaN   NaN   NaN  NaN  NaN
# 1       02t  2023-12-01  01:00:00  41.0   NaN   NaN   NaN  NaN  NaN
# 2       02t  2023-12-01  02:00:00  34.0   NaN   NaN   NaN  NaN  NaN
# 3       02t  2023-12-01  03:00:00  34.0   NaN   NaN   NaN  NaN  NaN
# 4       02t  2023-12-01  04:00:00  36.0   NaN   NaN   NaN  NaN  NaN
# ...     ...         ...       ...   ...   ...   ...   ...  ...  ...
# 129538  93t  2024-01-31  20:00:00  11.0  23.0  24.0  0.21  2.0  NaN
# 129539  93t  2024-01-31  21:00:00  12.0  24.0  23.0  0.20  1.0  NaN
# 129540  93t  2024-01-31  22:00:00  14.0  25.0  22.0  0.20  2.0  NaN
# 129541  93t  2024-01-31  23:00:00  15.0  29.0  20.0  0.20  2.0  NaN
# 129542  93t  2024-02-01  00:00:00   NaN   NaN   NaN   NaN  NaN  NaN
#
# [129543 rows x 9 columns]

# %%
columns_to_fill = ['pm25', 'pm10', 'o3', 'co', 'no2', 'so2']
fill_df[columns_to_fill] = fill_df[columns_to_fill].fillna(fill_df[columns_to_fill].mean())

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Plot the data using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x=df.index, y='pm25', label='Original Data', color='blue')
sns.lineplot(data=fill_df, x=fill_df.index, y='pm25', label='Mean Data', linestyle='dotted', color='red')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('PM2.5')
plt.title('Time Series of PM2.5 with Original Data (Blue) and Mean Data (Red)')

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Plot the data using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x=df.index, y='pm10', label='Original Data', color='blue')
sns.lineplot(data=fill_df, x=fill_df.index, y='pm10', label='Mean Data', linestyle='dotted', color='red')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('PM10')
plt.title('Time Series of PM10 with Original Data (Blue) and Mean Data (Red)')

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Plot the data using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x=df.index, y='o3', label='Original Data', color='blue')
sns.lineplot(data=fill_df, x=fill_df.index, y='o3', label='Mean Data', linestyle='dotted', color='red')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('O3')
plt.title('Time Series of O3 with Original Data (Blue) and Mean Data (Red)')

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Plot the data using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x=df.index, y='co', label='Original Data', color='blue')
sns.lineplot(data=fill_df, x=fill_df.index, y='co', label='Mean Data', linestyle='dotted', color='red')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('O3')
plt.title('Time Series of CO with Original Data (Blue) and Mean Data (Red)')

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Plot the data using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x=df.index, y='no2', label='Original Data', color='blue')
sns.lineplot(data=fill_df, x=fill_df.index, y='no2', label='Mean Data', linestyle='dotted', color='red')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('No2')
plt.title('Time Series of No2 with Original Data (Blue) and Mean Data (Red)')

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Plot the data using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x=df.index, y='so2', label='Original Data', color='blue')
sns.lineplot(data=fill_df, x=fill_df.index, y='so2', label='Mean Data', linestyle='dotted', color='red')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('So2')
plt.title('Time Series of So2 with Original Data (Blue) and Mean Data (Red)')

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
fill_df
# Out:
#          id        date      time       pm25       pm10         o3        co  \
# 0       02t  2023-12-01  00:00:00  33.000000  54.702032  27.635492  0.634761
# 1       02t  2023-12-01  01:00:00  41.000000  54.702032  27.635492  0.634761
# 2       02t  2023-12-01  02:00:00  34.000000  54.702032  27.635492  0.634761
# 3       02t  2023-12-01  03:00:00  34.000000  54.702032  27.635492  0.634761
# 4       02t  2023-12-01  04:00:00  36.000000  54.702032  27.635492  0.634761
# ...     ...         ...       ...        ...        ...        ...       ...
# 129538  93t  2024-01-31  20:00:00  11.000000  23.000000  24.000000  0.210000
# 129539  93t  2024-01-31  21:00:00  12.000000  24.000000  23.000000  0.200000
# 129540  93t  2024-01-31  22:00:00  14.000000  25.000000  22.000000  0.200000
# 129541  93t  2024-01-31  23:00:00  15.000000  29.000000  20.000000  0.200000
# 129542  93t  2024-02-01  00:00:00  30.406467  54.702032  27.635492  0.634761
#
#               no2       so2
# ...

# %%
fill_df.isnull().sum()
# Out:
# id      0
# date    0
# time    0
# pm25    0
# pm10    0
# o3      0
# co      0
# no2     0
# so2     0
# dtype: int64

# %%
msno.bar(fill_df)
# Out:
# <Axes: >

# %%
fill_df
# Out:
#          id        date      time       pm25       pm10         o3        co  \
# 0       02t  2023-12-01  00:00:00  33.000000  54.702032  27.635492  0.634761
# 1       02t  2023-12-01  01:00:00  41.000000  54.702032  27.635492  0.634761
# 2       02t  2023-12-01  02:00:00  34.000000  54.702032  27.635492  0.634761
# 3       02t  2023-12-01  03:00:00  34.000000  54.702032  27.635492  0.634761
# 4       02t  2023-12-01  04:00:00  36.000000  54.702032  27.635492  0.634761
# ...     ...         ...       ...        ...        ...        ...       ...
# 129538  93t  2024-01-31  20:00:00  11.000000  23.000000  24.000000  0.210000
# 129539  93t  2024-01-31  21:00:00  12.000000  24.000000  23.000000  0.200000
# 129540  93t  2024-01-31  22:00:00  14.000000  25.000000  22.000000  0.200000
# 129541  93t  2024-01-31  23:00:00  15.000000  29.000000  20.000000  0.200000
# 129542  93t  2024-02-01  00:00:00  30.406467  54.702032  27.635492  0.634761
#
#               no2       so2
# ...

# %%
# Set the style
sns.set(style="whitegrid")

# Define the columns you want to create boxplots for
columns_to_plot = ['pm25', 'pm10', 'o3', 'co', 'no2', 'so2']

# Create boxplots using Seaborn
plt.figure(figsize=(12, 6))
sns.boxplot(data=fill_df[columns_to_plot], orient="v", palette="Set3")
plt.title('Boxplots of Air Quality Parameters')
plt.ylabel('Value')
plt.xlabel('Parameter')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ![alt text](https://github.com/bestculling/Air-Pollution-PM2.5/blob/main/images/aqi_value.png?raw=true)

# %%
fill_df[fill_df['pm25'] > 75.1]
# Out:
#          id        date      time   pm25        pm10         o3        co  \
# 213     02t  2023-12-09  21:00:00   77.0   54.702032  27.635492  0.634761
# 214     02t  2023-12-09  22:00:00   89.0   54.702032  27.635492  0.634761
# 215     02t  2023-12-09  23:00:00  102.0   54.702032  27.635492  0.634761
# 216     02t  2023-12-10  00:00:00   98.0   54.702032  27.635492  0.634761
# 217     02t  2023-12-10  01:00:00   97.0   54.702032  27.635492  0.634761
# ...     ...         ...       ...    ...         ...        ...       ...
# 115666  98t  2024-01-12  05:00:00   77.0  106.000000  24.000000  0.760000
# 115684  98t  2024-01-12  23:00:00   77.0  115.000000  46.000000  0.740000
# 115685  98t  2024-01-13  00:00:00   76.0  109.000000  41.000000  0.720000
# 115851  98t  2024-01-19  22:00:00   80.0  119.000000  31.000000  0.780000
# 116045  98t  2024-01-28  00:00:00   76.0  100.000000  40.000000  0.820000
#
#               no2       so2
# 213     10.413959  1.776749
# ...

# %%
fill_df[fill_df['pm10'] > 181]
# Out:
#          id        date      time   pm25   pm10         o3    co   no2  \
# 16597   54t  2023-12-10  02:00:00   74.0  185.0  27.635492  1.67  69.0
# 16598   54t  2023-12-10  03:00:00   82.0  197.0  27.635492  1.62  63.0
# 16599   54t  2023-12-10  04:00:00   83.0  210.0  27.635492  1.48  58.0
# 16600   54t  2023-12-10  05:00:00   86.0  217.0  27.635492  1.64  58.0
# 16601   54t  2023-12-10  06:00:00   83.0  219.0  27.635492  1.88  38.0
# ...     ...         ...       ...    ...    ...        ...   ...   ...
# 105883  86t  2023-12-07  20:00:00  141.0  184.0  20.000000  0.66  24.0
# 111143  95t  2024-01-09  21:00:00   70.0  188.0  23.000000  1.09  24.0
# 111144  95t  2024-01-09  22:00:00   68.0  186.0  20.000000  0.99  12.0
# 112317  96t  2023-12-27  18:00:00  197.0  311.0  22.000000  0.90  29.0
# 112966  96t  2024-01-23  19:00:00  129.0  187.0  28.000000  0.83  11.0
#
#              so2
# 16597   1.776749
# 16598   1.776749
# 16599   1.776749
# 16600   1.776749
# 16601   1.776749
# ...

# %%
fill_df[fill_df['o3'] > 121]
# Out:
#           id        date      time  pm25       pm10     o3         co  \
# 7675     59t  2023-12-10  14:00:00  44.0  85.000000  128.0   0.634761
# 8924     59t  2024-01-31  15:00:00  44.0  74.000000  128.0   0.634761
# 26310    13t  2024-01-11  13:00:00  32.0  64.000000  176.0   0.634761
# 42859    84t  2024-01-18  15:00:00  56.0  79.000000  137.0   0.634761
# 60891   101t  2024-01-25  11:00:00  10.0  32.000000  128.0  11.030000
# 67315    31t  2023-12-13  22:00:00  60.0  54.702032  143.0   0.634761
# 73240    34t  2023-12-12  15:00:00  41.0  54.702032  123.0   0.634761
# 119434   44t  2023-12-14  02:00:00  16.0  54.702032  144.0   0.634761
# 120178   44t  2024-01-14  02:00:00  22.0  54.702032  140.0   0.634761
#
#               no2        so2
# 7675    10.413959   1.776749
# 8924    10.413959   1.776749
# 26310   10.413959   1.776749
# 42859   10.413959   1.776749
# 60891    4.000000  96.000000
# 67315   10.413959   1.776749
# 73240   10.413959   1.776749
# ...

# %%
fill_df[fill_df['co'] > 30.1]
# Out:
#         id        date      time  pm25  pm10    o3     co   no2  so2
# 44345  85t  2024-01-18  12:00:00  50.0  74.0  69.0  45.51   8.0  2.0
# 44346  85t  2024-01-18  13:00:00  43.0  60.0  72.0  60.22   9.0  1.0
# 44347  85t  2024-01-18  14:00:00  42.0  51.0  80.0  51.22   7.0  1.0
# 44348  85t  2024-01-18  15:00:00  40.0  51.0  81.0  51.44   6.0  1.0
# 44349  85t  2024-01-18  16:00:00  38.0  74.0  71.0  73.76  12.0  1.0

# %%
fill_df[fill_df['no2'] > 341]
# Out:
# Empty DataFrame
# Columns: [id, date, time, pm25, pm10, o3, co, no2, so2]
# Index: []

# %%
fill_df[fill_df['so2'] > 401]
# Out:
# Empty DataFrame
# Columns: [id, date, time, pm25, pm10, o3, co, no2, so2]
# Index: []

# %%
df = fill_df.drop(columns=['id'])

# Find duplicates based on 'date' and 'time' columns
duplicate_rows = df[df.duplicated(['date', 'time'], keep=False)]

if duplicate_rows.empty:
    print("No duplicate rows found.")
else:
    print("Duplicate rows found:")
    print(duplicate_rows)
# Out:
# Duplicate rows found:
#               date      time       pm25       pm10         o3        co  \
# 0       2023-12-01  00:00:00  33.000000  54.702032  27.635492  0.634761
# 1       2023-12-01  01:00:00  41.000000  54.702032  27.635492  0.634761
# 2       2023-12-01  02:00:00  34.000000  54.702032  27.635492  0.634761
# 3       2023-12-01  03:00:00  34.000000  54.702032  27.635492  0.634761
# 4       2023-12-01  04:00:00  36.000000  54.702032  27.635492  0.634761
# ...            ...       ...        ...        ...        ...       ...
# 129538  2024-01-31  20:00:00  11.000000  23.000000  24.000000  0.210000
# 129539  2024-01-31  21:00:00  12.000000  24.000000  23.000000  0.200000
# 129540  2024-01-31  22:00:00  14.000000  25.000000  22.000000  0.200000
# 129541  2024-01-31  23:00:00  15.000000  29.000000  20.000000  0.200000
# 129542  2024-02-01  00:00:00  30.406467  54.702032  27.635492  0.634761
#
#               no2       so2
# 0       10.413959  1.776749
# ...

# %%
fill_df
# Out:
#          id        date      time       pm25       pm10         o3        co  \
# 0       02t  2023-12-01  00:00:00  33.000000  54.702032  27.635492  0.634761
# 1       02t  2023-12-01  01:00:00  41.000000  54.702032  27.635492  0.634761
# 2       02t  2023-12-01  02:00:00  34.000000  54.702032  27.635492  0.634761
# 3       02t  2023-12-01  03:00:00  34.000000  54.702032  27.635492  0.634761
# 4       02t  2023-12-01  04:00:00  36.000000  54.702032  27.635492  0.634761
# ...     ...         ...       ...        ...        ...        ...       ...
# 129538  93t  2024-01-31  20:00:00  11.000000  23.000000  24.000000  0.210000
# 129539  93t  2024-01-31  21:00:00  12.000000  24.000000  23.000000  0.200000
# 129540  93t  2024-01-31  22:00:00  14.000000  25.000000  22.000000  0.200000
# 129541  93t  2024-01-31  23:00:00  15.000000  29.000000  20.000000  0.200000
# 129542  93t  2024-02-01  00:00:00  30.406467  54.702032  27.635492  0.634761
#
#               no2       so2
# ...

# %%
fill_df.to_csv('data/air_pollution_2024_with_prep.csv', index=False)

if os.path.exists('data/air_pollution_2024_with_prep.csv'):
    print("export success")
else:
    print("export failed")
# Out:
# export success
