# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
import folium
warnings.filterwarnings("ignore")

# %%
df_station = pd.read_csv('data/datasets/Bangkok_Metropolitan_Region.csv')
df_station
# Out:
#      id                                          location  \
# 0   02t                      แขวงหิรัญรูจี เขตธนบุรี กทม.
# 1   05t                           แขวงบางนา เขตบางนา กทม.
# 2   10t                      แขวงคลองจั่น เขตบางกะปิ กทม.
# 3   11t                         แขวงดินแดง เขตดินแดง กทม.
# 4   12t                     แขวงช่องนนทรี เขตยานนาวา กทม.
# 5   59t                           แขวงพญาไท เขตพญาไท กทม.
# 6   61t                    แขวงพลับพลา เขตวังทองหลาง กทม.
# 7   03t   ริมถนนกาญจนาภิเษก แขวงแสมดำ เขตบางขุนเทียน กทม.
# 8   50t       ริมถนนพระรามสี่ แขวงปทุมวัน เขตปทุมวัน กทม.
# 9   52t  ริมถนนอินทรพิทักษ์ แขวงบางยี่เรือ เขตธนบุรี กทม.
# 10  53t  ริมถนนลาดพร้าว แขวงวังทองหลาง เขตวังทองหลาง กทม.
# 11  54t            ริมถนนดินแดง แขวงดินแดง เขตดินแดง กทม.
# 12  08t               ต.ทรงคนอง อ.พระประแดง จ.สมุทรปราการ
# 13  16t                   ต.บางโปรง อ.เมือง จ.สมุทรปราการ
# 14  17t                  ต.ตลาด อ.พระประแดง จ.สมุทรปราการ
# 15  18t                    ต.ปากน้ำ อ.เมือง จ.สมุทรปราการ
# 16  19t               ต.บางเสาธง อ.บางเสาธง จ.สมุทรปราการ
# 17  13t                      ต.ตลาดขวัญ อ.เมือง จ.นนทบุรี
# 18  22t                     ต.บางพูด อ.ปากเกร็ด จ.นนทบุรี
# 19  14t               ต.อ้อมน้อย อ.กระทุ่มแบน จ.สมุทรสาคร
# 20  27t                      ต.มหาชัย อ.เมือง จ.สมุทรสาคร
# 21  20t                 ต.คลองหนึ่ง อ.คลองหลวง จ.ปทุมธานี
#
#                                            name  \
# 0          มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 1                              กรมอุตุนิยมวิทยา
# 2                             เคหะชุมชนคลองจั่น
# 3                     สนามกีฬาเคหะชุมชนห้วยขวาง
# 4                            โรงเรียนนนทรีวิทยา
# 5                              กรมประชาสัมพันธ์
# 6           โรงเรียนบดินทรเดชา (สิงห์ สิงหเสนี)
# 7                             ริมถนนกาญจนาภิเษก
# 8                           โรงพยาบาลจุฬาลงกรณ์
# 9                          สถานีไฟฟ้าย่อยธนบุรี
# 10                       สถานีตำรวจนครบาลโชคชัย
# 11                              เคหะชุมชนดินแดง
# 12  ศูนย์ฟื้นฟูอาชีพคนพิการและทุพพลภาพพระประแดง
# 13                            โรงไฟฟ้าพระนครใต้
# 14   บ้านพักกรมอุตสาหกรรมพื้นฐานและการเหมืองแร่
# 15                   ศาลากลางจังหวัดสมุทรปราการ
# 16                     เคหะชุมชนเมืองใหม่บางพลี
# 17                                 กรมควบคุมโรค
# 18                 มหาวิทยาลัยสุโขทัยธรรมาธิราช
# 19    หน่วยบริการตำรวจทางหลวงศรีสำราญ สมุทรสาคร
# 20                    โรงเรียนสมุทรสาครวิทยาลัย
# 21          มหาวิทยาลัยกรุงเทพ (วิทยาเขตรังสิต)
#
#                                 coordinate
# 0   13.732426463584861, 100.49015667339364
# 1    13.66791601805487, 100.60501734347488
# 2   13.768421204495263, 100.64995084428647
# 3    13.77908836851679, 100.56929369363229
# 4   13.707485082149482, 100.54709488013903
# 5     13.781508545396507, 100.538146780084
# 6   13.771671960826078, 100.61382751776014
# 7   13.645451937711213, 100.40560138710092
# 8    13.73388063294745, 100.53443553092688
# 9   13.729998592966359, 100.48601579371935
# 10  13.795463918748847, 100.59337753781288
# 11   13.764417628605102, 100.5542154232553
# 12   13.665465615411808, 100.5432724954825
# 13  13.621193693466568, 100.56054822828494
# 14  13.657892961478957, 100.53187451374706
# 15  13.599625747398735, 100.59697232616966
# 16  13.566463189928253, 100.77174295385399
# 17  13.853709121861604, 100.52713326665005
# 18  13.911580206170871, 100.53731385738904
# 19  13.705410536999299, 100.31528678384386
# 20   13.54950932636421, 100.26484700526724
# 21  14.039941950346151, 100.61347058821525

# %%
df_pm25 = pd.read_csv('data/air_pollution_2024_with_prep.csv')
df_pm25
# Out:
#          id        date      time       pm25       pm10         o3        co  \
# 0       02t  2023-12-01  00:00:00  33.000000  54.702032  27.635492  0.634761
# 1       02t  2023-12-01  01:00:00  41.000000  54.702032  27.635492  0.634761
# 2       02t  2023-12-01  02:00:00  34.000000  54.702032  27.635492  0.634761
# 3       02t  2023-12-01  03:00:00  34.000000  54.702032  27.635492  0.634761
# 4       02t  2023-12-01  04:00:00  36.000000  54.702032  27.635492  0.634761
# ...     ...         ...       ...        ...        ...        ...       ...
# 129538  93t  2024-01-31  20:00:00  11.000000  23.000000  24.000000  0.210000
# 129539  93t  2024-01-31  21:00:00  12.000000  24.000000  23.000000  0.200000
# 129540  93t  2024-01-31  22:00:00  14.000000  25.000000  22.000000  0.200000
# 129541  93t  2024-01-31  23:00:00  15.000000  29.000000  20.000000  0.200000
# 129542  93t  2024-02-01  00:00:00  30.406467  54.702032  27.635492  0.634761
#
#               no2       so2
# 0       10.413959  1.776749
# 1       10.413959  1.776749
# 2       10.413959  1.776749
# 3       10.413959  1.776749
# 4       10.413959  1.776749
# ...           ...       ...
# 129538   2.000000  1.776749
# 129539   1.000000  1.776749
# 129540   2.000000  1.776749
# 129541   2.000000  1.776749
# 129542  10.413959  1.776749
#
# [129543 rows x 9 columns]

# %%
df_pm25 = df_pm25[['id', 'date', 'time', 'pm25']]
df_pm25
# Out:
#          id        date      time       pm25
# 0       02t  2023-12-01  00:00:00  33.000000
# 1       02t  2023-12-01  01:00:00  41.000000
# 2       02t  2023-12-01  02:00:00  34.000000
# 3       02t  2023-12-01  03:00:00  34.000000
# 4       02t  2023-12-01  04:00:00  36.000000
# ...     ...         ...       ...        ...
# 129538  93t  2024-01-31  20:00:00  11.000000
# 129539  93t  2024-01-31  21:00:00  12.000000
# 129540  93t  2024-01-31  22:00:00  14.000000
# 129541  93t  2024-01-31  23:00:00  15.000000
# 129542  93t  2024-02-01  00:00:00  30.406467
#
# [129543 rows x 4 columns]

# %%
filtered_pm25 = df_pm25[df_pm25['id'].isin(df_station['id'])]
filtered_pm25
# Out:
#         id        date      time       pm25
# 0      02t  2023-12-01  00:00:00  33.000000
# 1      02t  2023-12-01  01:00:00  41.000000
# 2      02t  2023-12-01  02:00:00  34.000000
# 3      02t  2023-12-01  03:00:00  34.000000
# 4      02t  2023-12-01  04:00:00  36.000000
# ...    ...         ...       ...        ...
# 32753  20t  2024-01-31  20:00:00  66.000000
# 32754  20t  2024-01-31  21:00:00  86.000000
# 32755  20t  2024-01-31  22:00:00  85.000000
# 32756  20t  2024-01-31  23:00:00  91.000000
# 32757  20t  2024-02-01  00:00:00  30.406467
#
# [32758 rows x 4 columns]

# %%
# print(filtered_pm25[filtered_pm25['id'] == '02t']['pm25'].mean())

# for i in df_station['id']:
#     print(i)

# %%
data_coordinate = df_station['coordinate']
coordinates = []
for i in data_coordinate:
    latitude, longitude = i.split(",")
    coordinates.append([float(latitude), float(longitude)])
coordinates
# Out:
# [[13.732426463584861, 100.49015667339364],
#  [13.66791601805487, 100.60501734347488],
#  [13.768421204495263, 100.64995084428647],
#  [13.77908836851679, 100.56929369363229],
#  [13.707485082149482, 100.54709488013903],
#  [13.781508545396507, 100.538146780084],
#  [13.771671960826078, 100.61382751776014],
#  [13.645451937711213, 100.40560138710092],
#  [13.73388063294745, 100.53443553092688],
#  [13.729998592966359, 100.48601579371935],
#  [13.795463918748847, 100.59337753781288],
#  [13.764417628605102, 100.5542154232553],
#  [13.665465615411808, 100.5432724954825],
#  [13.621193693466568, 100.56054822828494],
#  [13.657892961478957, 100.53187451374706],
#  [13.599625747398735, 100.59697232616966],
#  [13.566463189928253, 100.77174295385399],
#  [13.853709121861604, 100.52713326665005],
#  [13.911580206170871, 100.53731385738904],
#  [13.705410536999299, 100.31528678384386],
#  [13.54950932636421, 100.26484700526724],
#  [14.039941950346151, 100.61347058821525]]

# %%
data_name = df_station['name']
for i in range(len(data_name)):
    coordinates[i].append(data_name[i])
    pm25 = filtered_pm25[filtered_pm25['id'] == df_station['id'][i]]['pm25'].mean()
    coordinates[i].append(round(pm25, 2))
    coordinates[i].append(df_station['id'][i])
coordinates
# Out:
# [[13.732426463584861,
#   100.49015667339364,
#   'มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา',
#   41.19,
#   '02t'],
#  [13.66791601805487, 100.60501734347488, 'กรมอุตุนิยมวิทยา', 36.14, '05t'],
#  [13.768421204495263, 100.64995084428647, 'เคหะชุมชนคลองจั่น', 30.41, '10t'],
#  [13.77908836851679,
#   100.56929369363229,
#   'สนามกีฬาเคหะชุมชนห้วยขวาง',
#   31.73,
#   '11t'],
#  [13.707485082149482, 100.54709488013903, 'โรงเรียนนนทรีวิทยา', 32.58, '12t'],
#  [13.781508545396507, 100.538146780084, 'กรมประชาสัมพันธ์', 25.07, '59t'],
#  [13.771671960826078,
#   100.61382751776014,
#   'โรงเรียนบดินทรเดชา (สิงห์ สิงหเสนี)',
#   29.14,
#   '61t'],
#  [13.645451937711213, 100.40560138710092, 'ริมถนนกาญจนาภิเษก', 41.32, '03t'],
#  [13.73388063294745, 100.53443553092688, 'โรงพยาบาลจุฬาลงกรณ์', 36.65, '50t'],
#  [13.729998592966359,
#   100.48601579371935,
#   'สถานีไฟฟ้าย่อยธนบุรี',
#   37.64,
#   '52t'],
#  [13.795463918748847,
#   100.59337753781288,
#   'สถานีตำรวจนครบาลโชคชัย',
#   36.77,
#   '53t'],
#  [13.764417628605102, 100.5542154232553, 'เคหะชุมชนดินแดง', 42.08, '54t'],
#  [13.665465615411808,
#   100.5432724954825,
#   'ศูนย์ฟื้นฟูอาชีพคนพิการและทุพพลภาพพระประแดง',
#   40.61,
#   '08t'],
#  [13.621193693466568, 100.56054822828494, 'โรงไฟฟ้าพระนครใต้', 31.54, '16t'],
#  [13.657892961478957,
#   100.53187451374706,
#   'บ้านพักกรมอุตสาหกรรมพื้นฐานและการเหมืองแร่',
#   28.24,
#   '17t'],
#  [13.599625747398735,
#   100.59697232616966,
#   'ศาลากลางจังหวัดสมุทรปราการ',
#   49.6,
#   '18t'],
#  [13.566463189928253,
#   100.77174295385399,
#   'เคหะชุมชนเมืองใหม่บางพลี',
#   33.05,
#   '19t'],
#  [13.853709121861604, 100.52713326665005, 'กรมควบคุมโรค', 33.49, '13t'],
#  [13.911580206170871,
#   100.53731385738904,
#   'มหาวิทยาลัยสุโขทัยธรรมาธิราช',
#   47.1,
#   '22t'],
#  [13.705410536999299,
#   100.31528678384386,
#   'หน่วยบริการตำรวจทางหลวงศรีสำราญ สมุทรสาคร',
#   43.91,
#   '14t'],
#  [13.54950932636421,
#   100.26484700526724,
#   'โรงเรียนสมุทรสาครวิทยาลัย',
#   52.01,
#   '27t'],
#  [14.039941950346151,
#   100.61347058821525,
#   'มหาวิทยาลัยกรุงเทพ (วิทยาเขตรังสิต)',
#   39.11,
#   '20t']]

# %%
map = folium.Map(location=[13.66791601805487, 100.60501734347488], zoom_start=12)
for coordinate in coordinates:
    html = f"""
<div style="text-align: center">
  <h2>[{coordinate[4]}] {coordinate[2]}</h2>
  <h3>ค่าฝุ่น PM2.5 {coordinate[3]}</h3>
</div>
"""

    if coordinate[3] >= 75.1:
        color = "red"
    elif coordinate[3] >= 37.6:
        color = "orange"
    elif coordinate[3] >= 25.1:
        color = "yellow"
    elif coordinate[3] >= 15.1:
        color = "green"
    elif coordinate[3] >= 0:
        color = "blue"
    marker = folium.Marker(location=[coordinate[0], 
                                     coordinate[1]], 
                           popup = html,
                           tooltip="รายละเอียด",
                          icon=folium.Icon(color=color, icon="cloud"),
                          )
    marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdf05a203d71579eacc30d6229b46b33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdf05a203d71579eacc30d6229b46b33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdf05a203d71579eacc30d6229b46b33 = L.map(
#                 &quot;map_bdf05a203d71579eacc30d6229b46b33&quot;,
#                 {
#                     center: [13.66791601805487, 100.60501734347488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad50abddd20226c4df9d6e8e499d0714 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad50abddd20226c4df9d6e8e499d0714.addTo(map_bdf05a203d71579eacc30d6229b46b33);
#
#
#             var marker_7fa43718189222542acf7609f2ee5142 = L.marker(
#                 [13.732426463584861, 100.49015667339364],
#                 {}
#             ).addTo(map_bdf05a203d71579eacc30d6229b46b33);
#
#
#             var icon_e4b0f9219e4154c62f1a156594f22eb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fa43718189222542acf7609f2ee5142.setIcon(icon_e4b0f9219e4154c62f1a156594f22eb5);
#
#
#         var popup_90bfa1a36233c89950be6d89f474ef51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd40267eee5720040262dd33d7342366 = $(`&lt;div id=&quot;html_bd40267eee5720040262dd33d7342366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &lt;div style=&quot;text-align: center&quot;&gt;   &lt;h2&gt;[02t] มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา&lt;/h2&gt;   &lt;h3&gt;ค่าฝุ่น PM2.5 41.19&lt;/h3&gt; &lt;/div&gt; &lt;/div&gt;`)[0];
#                 popup_90bfa1a36233c89950be6d89f474ef51.setContent(html_bd40267eee5720040262dd33d7342366);
#
#
#
#         marker_7fa43718189222542acf7609f2ee5142.bindPopup(popup_90bfa1a36233c89950be6d89f474ef51)
#         ;
#
#
#
#
#             marker_7fa43718189222542acf7609f2ee5142.bindTooltip(
#                 `&lt;div&gt;
#                      รายละเอียด
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_15d475fb00b550e692cc2ede6a44399c = L.marker(
#                 [13.66791601805487, 100.60501734347488],
#                 {}
#             ).addTo(map_bdf05a203d71579eacc30d6229b46b33);
#
#
#             var icon_4c4760f3a552111836107ccdabb20016 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_15d475fb00b550e692cc2ede6a44399c.setIcon(icon_4c4760f3a552111836107ccdabb20016);
#
#
#         var popup_94a09b0b0fd5666eb6264e28c50b9dfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_537dbf704d1729a21353afcfdef294d6 = $(`&lt;div id=&quot;html_537dbf704d1729a21353afcfdef294d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &lt;div style=&quot;text-align: center&quot;&gt;   &lt;h2&gt;[05t] กรมอุตุนิยมวิทยา&lt;/h2&gt;   &lt;h3&gt;ค่าฝุ่น PM2.5 36.14&lt;/h3&gt; &lt;/div&gt; &lt;/div&gt;`)[0];
#                 popup_94a09b0b0fd5666eb6264e28c50b9dfd.setContent(html_537dbf704d1729a21353afcfdef294d6);
#
#
#
#         marker_15d475fb00b550e692cc2ede6a44399c.bindPopup(popup_94a09b0b0fd5666eb6264e28c50b9dfd)
#         ;
#
#
#
#
#             marker_15d475fb00b550e692cc2ede6a44399c.bindTooltip(
#                 `&lt;div&gt;
#                      รายละเอียด
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_11aac48516ea1b8d7a96f61893f07d83 = L.marker(
#                 [13.768421204495263, 100.64995084428647],
#                 {}
#             ).addTo(map_bdf05a203d71579eacc30d6229b46b33);
#
#
#             var icon_fbaa6cba1bdb8194f12b9e2f680c83d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_11aac48516ea1b8d7a96f61893f07d83.setIcon(icon_fbaa6cba1bdb8194f12b9e2f680c83d3);
#
#
#         var popup_cc0f703007ce67eae0fb653389b53a10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0972d05446c3555e28f80da6e31bef53 = $(`&lt;div id=&quot;html
